# %%
import numpy as np
import cv2

image1 = cv2.imread("/Users/pflomacpro/RLG/Data/15-09-03/Level18/Trim001_1.png")
image2 = cv2.imread("/Users/pflomacpro/RLG/Data/15-09-03/Level18/Trim001_2.png")
image3 = image1 - image2

cv2.imshow('image3',image3)
cv2.waitKey(0)
cv2.destroyAllWindows()
